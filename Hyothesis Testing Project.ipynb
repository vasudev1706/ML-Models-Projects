# %% [markdown]
# LABTAT DATASET

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df=pd.read_csv("/content/LabTAT.csv")

# %%
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
lab1= df["Laboratory 1"]
lab2= df["Laboratory 2"]
lab3= df["Laboratory 3"]
lab4 = df["Laboratory 4"]

# %%
# Performing one-way ANOVA
f_statistic, p_value = stats.f_oneway(lab1, lab2, lab3, lab4)

# %%
# Setting the significance level
alpha = 0.05

# %%
#results

# %%
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 118.70421654401437
# P-value: 2.1156708949992414e-57

# %%
# Checking the p-value against the significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in average TAT.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in average TAT.")
# Out:
# Reject the null hypothesis. There is a significant difference in average TAT.

# %% [markdown]
# CUTLETS DATASET

# %%
df1=pd.read_csv("/content/Cutlets.csv")

# %%
df1
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
unit_a= df1["Unit A"]
unit_b= df1["Unit B"]

# %%
# Assumption checks
_, p_value_a = stats.shapiro(unit_a)
_, p_value_b = stats.shapiro(unit_b)

_, p_value_var = stats.levene(unit_a, unit_b)

# %%
# Two-sample t-test
t_statistic, p_value_ttest = stats.ttest_ind(unit_a, unit_b)

# %%
# Display results
print(f"Shapiro-Wilk test for normality (Unit A): p-value = {p_value_a:.4f}")
print(f"Shapiro-Wilk test for normality (Unit B): p-value = {p_value_b:.4f}")
print(f"Levene's test for homogeneity of variance: p-value = {p_value_var:.4f}")

print("\nTwo-sample t-test results:")
print(f"t-statistic = {t_statistic:.4f}")
print(f"p-value = {p_value_ttest:.4f}")
# Out:
# Shapiro-Wilk test for normality (Unit A): p-value = 0.3200
# Shapiro-Wilk test for normality (Unit B): p-value = 0.5225
# Levene's test for homogeneity of variance: p-value = 0.4176
#
# Two-sample t-test results:
# t-statistic = 0.7229
# p-value = 0.4722

# %%
# Interpret the results
alpha = 0.05
if p_value_a > alpha and p_value_b > alpha and p_value_var > alpha:
    print("\nAssumptions met. There is no significant difference.")
    print("Fail to reject the null hypothesis.")
else:
    print("\nAssumptions not met or p-value < 0.05. There is a significant difference.")
    print("Reject the null hypothesis.")
# Out:
# Assumptions met. There is no significant difference.
# Fail to reject the null hypothesis.

# %% [markdown]
# BUYER RATION DATASET

# %%
df2= pd.read_csv("/content/BuyerRatio.csv")

# %%
df2
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
observed = [[50, 142, 131, 70],
            [435, 1523, 1356, 750]]

# Perform chi-square test
chi2_stat, p_value, _, _ = stats.chi2_contingency(observed)

# Print the p-value
print("P-value:", p_value)
# Out:
# P-value: 0.6603094907091882

# %%
#as the p value is greater than the alpha we reject null hypothesis

# %% [markdown]
# CUSTOMER ORDERFORM DATASET

# %%
df3= pd.read_csv("/content/Costomer+OrderForm.csv")

# %%
df3
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
from scipy.stats import chi2_contingency

# %%
contingency_table = pd.crosstab(df3["Phillippines"], [df3['Indonesia'], df3['Malta'], df3['India']], margins=True)

# %%
contingency_table
# Out:
# Indonesia     Defective                       Error Free             \
# Malta         Defective Error Free             Defective Error Free
# India        Error Free  Defective Error Free Error Free  Defective
# Phillippines
# Defective             0          0          2          4          2
# Error Free            9          2         20         18         16
# All                   9          2         22         22         18
#
# Indonesia                All
# Malta
# India        Error Free
# Phillippines
# Defective            21   29
# Error Free          206  271
# All                 227  300

# %%
# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# %%
# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies table:")
print(expected)
# Out:
# Chi-square statistic: 3.100139559251226
# P-value: 0.994794785918027
# Degrees of freedom: 12
# Expected frequencies table:
# [[8.70000000e-01 1.93333333e-01 2.12666667e+00 2.12666667e+00
#   1.74000000e+00 2.19433333e+01 2.90000000e+01]
#  [8.13000000e+00 1.80666667e+00 1.98733333e+01 1.98733333e+01
#   1.62600000e+01 2.05056667e+02 2.71000000e+02]
#  [9.00000000e+00 2.00000000e+00 2.20000000e+01 2.20000000e+01
#   1.80000000e+01 2.27000000e+02 3.00000000e+02]]

# %%
# Compare p-value to significance level (alpha)
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis. There is a significant association between center and defective/error-free status.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between center and defective/error-free status.")
# Out:
# Fail to reject the null hypothesis. There is no significant association between center and defective/error-free status.
